# %%
import contextily as cx
import osmnx as ox

# %%
groceries = ox.geometries_from_place("Richardson, TX", tags={"shop": ["grocery", "supermarket"]})
print(f"There are {len(groceries)} results in the groceries result")
groceries.head()
# Out:
# There are 17 results in the groceries result
#                                            geometry                    name
# element_type osmid
# node         5691554218  POINT (-96.69907 32.94699)            India Bazaar  \
#              5844878585  POINT (-96.70202 32.93240)             Fiesta Mart
#              6556113806  POINT (-96.76506 32.97694)  Sprouts Farmers Market
#              6997646700  POINT (-96.74245 32.97707)         Natural Grocers
#              8653941971  POINT (-96.69652 32.94577)                    ALDI
#
#                                 shop                   brand brand:wikidata
# element_type osmid
# node         5691554218  supermarket                     NaN            NaN  \
#              5844878585  supermarket             Fiesta Mart       Q5447326
#              6556113806  supermarket  Sprouts Farmers Market       Q7581369
#              6997646700  supermarket         Natural Grocers      Q17146520
# ...

# %%
ax = groceries.plot()
cx.add_basemap(ax=ax, crs=groceries.crs.to_string())

# %%
cols2keep = ["geometry", "name", "shop", "brand"]
groceries.geometry = groceries.geometry.centroid
groceries[cols2keep].to_file("data/OSMGroceries.gpkg")
# Out:
# /tmp/ipykernel_863/1080391269.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   groceries.geometry = groceries.geometry.centroid

# %%
schools = ox.geometries_from_place("Richardson, TX", tags={"amenity": ["school", "university"]})
print(f"There are {len(schools)} results in the schools result")
schools.head()
# Out:
# There are 38 results in the schools result
#                          amenity  ele gnis:feature_id
# element_type osmid
# node         356707107    school  189         1336982  \
#              356794393    school  195         2004190
#              356858941    school  185         2428794
#              356858959    school  182         2428802
#              12650556320  school  NaN             NaN
#
#                                                             name
# element_type osmid
# node         356707107                  Greenville Avenue School  \
#              356794393    Richardson Alternative Learning Center
#              356858941         Christa McAuliffe Learning Center
#              356858959          Evolution Academy Charter School
#              12650556320          math science technology magnet
#
#                                             geometry addr:city
# element_type osmid
# node         356707107    POINT (-96.73278 32.94568)       NaN  \
# ...

# %%
ax = schools.plot()
cx.add_basemap(ax=ax, crs=schools.crs.to_string())

# %%
cols2keep = ["geometry", "name"]
schools.geometry = schools.geometry.centroid
schools[cols2keep].to_file("data/OSMSchools.gpkg")
# Out:
# /tmp/ipykernel_863/4083603265.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   schools.geometry = schools.geometry.centroid

# %%
restaurants = ox.geometries_from_place("Richardson, TX", tags={"amenity": ["restaurant"]})
print(f"There are {len(restaurants)} results in the restaurants result")
restaurants.head()
# Out:
# There are 154 results in the restaurants result
#                           addr:city addr:housenumber addr:postcode addr:state
# element_type osmid
# node         825408480   Richardson              515         75080         TX  \
#              1566556495         NaN              NaN           NaN        NaN
#              1572029534  Richardson              101           NaN        NaN
#              1584212156  Richardson             1251         75080         TX
#              1584213492         NaN              NaN           NaN        NaN
#
#                                 addr:street     amenity         brand
# element_type osmid
# node         825408480   West Campbell Road  restaurant     Pizza Hut  \
#              1566556495                 NaN  restaurant           NaN
#              1572029534     South Coit Road  restaurant  Jason's Deli
#              1584212156  West Campbell Road  restaurant           NaN
# ...

# %%
ax = restaurants.plot()
cx.add_basemap(ax=ax, crs=restaurants.crs.to_string())

# %%
cols2keep = ["geometry", "name", "brand", "cuisine"]
restaurants.geometry = restaurants.geometry.centroid
restaurants[cols2keep].to_file("data/OSMRestaurants.gpkg")
# Out:
# /tmp/ipykernel_863/2957760405.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   restaurants.geometry = restaurants.geometry.centroid

# %%
busstops = ox.geometries_from_place("Richardson, TX", tags={"highway": ["bus_stop"]})
print(f"There are {len(busstops)} results in the schools result")
busstops.head()
# Out:
# There are 130 results in the schools result
#                          bus   highway public_transport
# element_type osmid
# node         566522167   yes  bus_stop    stop_position  \
#              4214685116  yes  bus_stop    stop_position
#              5579559899  yes  bus_stop         platform
#              5579559900  yes  bus_stop         platform
#              5579559902  yes  bus_stop         platform
#
#                                            geometry bench  bin covered
# element_type osmid
# node         566522167   POINT (-96.72191 32.96248)   NaN  NaN     NaN  \
#              4214685116  POINT (-96.73761 32.94096)   NaN  NaN     NaN
#              5579559899  POINT (-96.72558 32.99736)    no   no      no
#              5579559900  POINT (-96.72636 32.99764)    no  NaN      no
#              5579559902  POINT (-96.73064 32.99768)   yes  yes     yes
#
#                                                     name network
# element_type osmid
# ...

# %%
ax = busstops.plot()
cx.add_basemap(ax=ax, crs=busstops.crs.to_string())

# %%
cols2keep = ["geometry"]
busstops.geometry = busstops.geometry.centroid
busstops[cols2keep].to_file("data/OSMBusStops.gpkg")
# Out:
# /tmp/ipykernel_863/2149728096.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   busstops.geometry = busstops.geometry.centroid
