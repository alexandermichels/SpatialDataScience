# %% [markdown]
# # GGIS 4381/6321 - Lab 3 - Spatial Data
#
# **Authors:** Alexander Michels
#
# This notebook goes through the basics of working with spatial data in Python.

# %% [markdown]
# <hr id="pandas" />
#
# # Tabular Data with Pandas
#
# The Pandas package is a popular tool for working with tabular (table-like, think spreadsheets) data in Python. For example, to read a CSV (Comma Separated Values) file, we can use the `read_csv` function:

# %%
import pandas as pd
df = pd.read_csv("data/Texas_county.csv")

# %% [markdown]
# We can get a preview of the data with the `head` function which displays the first 5 entries in our DataFrame (the pandas name for a table):

# %%
df.head()
# Out:
#             COUNTY   FIPS                LOCATION    AREA_SQMI  E_TOTPOP
# 0  Anderson County  48001  Anderson County, Texas  1062.616344     58077  \
# 1   Andrews County  48003   Andrews County, Texas  1500.720658     18362
# 2  Angelina County  48005  Angelina County, Texas   797.864652     86608
# 3   Aransas County  48007   Aransas County, Texas   252.068582     24048
# 4    Archer County  48009    Archer County, Texas   903.288792      8649
#
#    M_TOTPOP
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# Just like with ESRI products (e.g., ArcGIS Online), data can have types in Pandas DataFrames. Let's check the types our data was loaded with.
#
# Below we will use a for loop to examine each column `col` in our DataFrame's `columns`. We will use an f-string (which allows us to easily print out variables) to print the name of the column and also the datatypes (`dtypes`) within that column.

# %%
for col in df.columns:
    print(f"{col}: {df[col].dtypes}")
# Out:
# COUNTY: object
# FIPS: int64
# LOCATION: object
# AREA_SQMI: float64
# E_TOTPOP: int64
# M_TOTPOP: int64

# %% [markdown]
# Note that our DataFrame loaded the FIPS codes as an `int64`. This means an integer with 64 bits (64 0s or 1s). It will be easier to work with FIPS values as strings:

# %%
df["FIPS"] = df["FIPS"].astype(str)  # set the FIPS column in the DataFrame to the FIPS column as the string type

# %% [markdown]
# Texas is lucky in that it has the state code `48`, but not all states are as lucky! Some states start with a leading zero and when loaded as an integer, this leading zero can be dropped. However, we can add leading zeroes to a FIPS code using the [pandas pad function](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.pad.html).
#
# We will pad up to 10 characters just to demonstrate the functionality, but note that county FIPS values are 5 digits.

# %%
df["Alex"] = df["FIPS"].str.pad(9, side="left", fillchar="0")  # pad the strings on the left side, up to 5 characters and use "0" to fill in.
df.head()
# Out:
#             COUNTY   FIPS                LOCATION    AREA_SQMI  E_TOTPOP
# 0  Anderson County  48001  Anderson County, Texas  1062.616344     58077  \
# 1   Andrews County  48003   Andrews County, Texas  1500.720658     18362
# 2  Angelina County  48005  Angelina County, Texas   797.864652     86608
# 3   Aransas County  48007   Aransas County, Texas   252.068582     24048
# 4    Archer County  48009    Archer County, Texas   903.288792      8649
#
#    M_TOTPOP       Alex
# 0         0  000048001
# 1         0  000048003
# 2         0  000048005
# 3         0  000048007
# 4         0  000048009

# %% [markdown]
# Pandas has some other valuable functionalities, like easily checking if a column is unique ([`is_unique`](https://pandas.pydata.org/docs/reference/api/pandas.Series.is_unique.html)):

# %%
df["FIPS"].is_unique
# Out:
# True

# %% [markdown]
# <hr id="geopandas" />
#
# ## Spatial Data with Geopandas
#
# The geopandas package builds on pandas, with the key difference being that GeoDataFrames have a "geometry" column!
#
# Let's load a sample dataset with Geopandas (*you can ignore the warning*):

# %%
import geopandas as gpd

gdf = gpd.read_file("data/UTD.gpkg")

# %% [markdown]
# GeoDataFrames are also DataFrames, so all of the tools we can use with Pandas still apply here! Let's get a preview of the data:

# %%
gdf.head()
# Out:
#   element_type      osmid                      name    building
# 0          way  134921833       Parking Structure 4      garage  \
# 1          way  221316815   Administration Building  university
# 2          way  221317000        Classroom Building  university
# 3          way  221317443  Eugene McDermott Library  university
# 4          way  221344894                         2  apartments
#
#                                             geometry
# 0  POLYGON ((1802977.859 7656229.698, 1802977.927...
# 1  POLYGON ((1803310.634 7656558.280, 1803309.909...
# 2  POLYGON ((1803277.536 7656609.044, 1803277.561...
# 3  POLYGON ((1803459.732 7656334.511, 1803459.799...
# 4  POLYGON ((1802810.950 7656087.852, 1802803.092...

# %% [markdown]
# We can use the `is_unique` property as well:

# %%
gdf["osmid"].is_unique
# Out:
# True

# %% [markdown]
# Because GeoDataFrames have a geometry column, we can plot them! GeoDataFrames have a built-in `plot()` method:

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# The values you see on the x- and y-axis don't appear to make much sense! We can check the Coordinate Reference System (CRS) by checking that propery of the GeoDataFrame:

# %%
gdf.crs
# Out:
# <Derived Projected CRS: EPSG:3083>
# Name: NAD83 / Texas Centric Albers Equal Area
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Texas.
# - bounds: (-106.66, 25.83, -93.5, 36.5)
# Coordinate Operation:
# - name: Texas Centric Albers Equal Area
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# To convert a GeoDataFrame to another CRS, we use the [`to_crs`](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.to_crs.html) method and specify the "Authority String" that specifies the projection we want to use.
#
# The most common projection is the EPSG:4326 one, let's project to that:

# %%
gdf = gdf.to_crs("EPSG:4326")

# %% [markdown]
# Then we can check our result:

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# GeoDataFrames also have a powerful `explore()` method to create quick interactive maps with basemaps!

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0765d5a6cde4f49b5d592492197ef2da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0765d5a6cde4f49b5d592492197ef2da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0765d5a6cde4f49b5d592492197ef2da = L.map(
#                 &quot;map_0765d5a6cde4f49b5d592492197ef2da&quot;,
#                 {
#                     center: [32.98829045000001, -96.75160400000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0765d5a6cde4f49b5d592492197ef2da);
#
#
#
#
#
#             var tile_layer_bcdc5df4a7d7cda07c38c4aa7bc428b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0765d5a6cde4f49b5d592492197ef2da);
#
#
#             map_0765d5a6cde4f49b5d592492197ef2da.fitBounds(
#                 [[32.97982639999997, -96.7587674], [32.99675450000004, -96.74444060000002]],
#                 {}
#             );
#
#
#         function geo_json_b36a0f3a2d22f917e93e64420d38eafe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b36a0f3a2d22f917e93e64420d38eafe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b36a0f3a2d22f917e93e64420d38eafe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b36a0f3a2d22f917e93e64420d38eafe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b36a0f3a2d22f917e93e64420d38eafe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b36a0f3a2d22f917e93e64420d38eafe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b36a0f3a2d22f917e93e64420d38eafe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b36a0f3a2d22f917e93e64420d38eafe = L.geoJson(null, {
#                 onEachFeature: geo_json_b36a0f3a2d22f917e93e64420d38eafe_onEachFeature,
#
#                 style: geo_json_b36a0f3a2d22f917e93e64420d38eafe_styler,
#                 pointToLayer: geo_json_b36a0f3a2d22f917e93e64420d38eafe_pointToLayer
#         });
#
#         function geo_json_b36a0f3a2d22f917e93e64420d38eafe_add (data) {
#             geo_json_b36a0f3a2d22f917e93e64420d38eafe
#                 .addData(data)
#                 .addTo(map_0765d5a6cde4f49b5d592492197ef2da);
#         }
#             geo_json_b36a0f3a2d22f917e93e64420d38eafe_add({&quot;bbox&quot;: [-96.7587674, 32.97982639999997, -96.74444060000002, 32.99675450000004], &quot;features&quot;: [{&quot;bbox&quot;: [-96.75358800000001, 32.98577759999998, -96.7524197, 32.986473099999984], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-96.7524641, 32.98647249999999], [-96.7524643, 32.986446099999945], [-96.7524678, 32.98589440000002], [-96.7524197, 32.9858942], [-96.7524204, 32.98577759999998], [-96.7525338, 32.985778099999976], [-96.7525337, 32.985790099999996], [-96.7525718, 32.985790200000004], [-96.75358800000001, 32.98579459999998], [-96.7535865, 32.98603630000005], [-96.7535855, 32.98620150000002], [-96.753584

# %% [markdown]
# <hr id="data-ops" />
#
# ## Data Operations
#
# Pandas and Geopandas both provide powerful tools for data operations. We have already explored a few including padding values, transforming data types, and converting between CRS.
#
# Here, we will perform some normal and spatial joins! Let's start by loading a GeoPackage of Texas counties.

# %%
tx = gpd.read_file("data/TXCounties.gpkg")
tx.head()
# Out:
#     FIPS                                           geometry
# 0  48001  MULTIPOLYGON (((-96.06486 31.98095, -96.06305 ...
# 1  48003  MULTIPOLYGON (((-103.06470 32.52219, -103.0004...
# 2  48005  MULTIPOLYGON (((-95.00488 31.42396, -95.00334 ...
# 3  48007  MULTIPOLYGON (((-97.12560 28.25371, -97.12500 ...
# 4  48009  MULTIPOLYGON (((-98.95382 33.49637, -98.95377 ...

# %%
tx.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a90c4949a87273b0e464c55092830f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a90c4949a87273b0e464c55092830f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a90c4949a87273b0e464c55092830f8 = L.map(
#                 &quot;map_3a90c4949a87273b0e464c55092830f8&quot;,
#                 {
#                     center: [31.16904050000005, -100.07696899999996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3a90c4949a87273b0e464c55092830f8);
#
#
#
#
#
#             var tile_layer_523cd0ba72c037768d706930813944ab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a90c4949a87273b0e464c55092830f8);
#
#
#             map_3a90c4949a87273b0e464c55092830f8.fitBounds(
#                 [[25.83737700000006, -106.64564599999994], [36.50070400000004, -93.50829199999998]],
#                 {}
#             );
#
#
#         function geo_json_226e6457daf82fc5b37235bbff5a9c23_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_226e6457daf82fc5b37235bbff5a9c23_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_226e6457daf82fc5b37235bbff5a9c23_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_226e6457daf82fc5b37235bbff5a9c23_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_226e6457daf82fc5b37235bbff5a9c23_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_226e6457daf82fc5b37235bbff5a9c23.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_226e6457daf82fc5b37235bbff5a9c23_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_226e6457daf82fc5b37235bbff5a9c23 = L.geoJson(null, {
#                 onEachFeature: geo_json_226e6457daf82fc5b37235bbff5a9c23_onEachFeature,
#
#                 style: geo_json_226e6457daf82fc5b37235bbff5a9c23_styler,
#                 pointToLayer: geo_json_226e6457daf82fc5b37235bbff5a9c23_pointToLayer
#         });
#
#         function geo_json_226e6457daf82fc5b37235bbff5a9c23_add (data) {
#             geo_json_226e6457daf82fc5b37235bbff5a9c23
#                 .addData(data)
#                 .addTo(map_3a90c4949a87273b0e464c55092830f8);
#         }
#             geo_json_226e6457daf82fc5b37235bbff5a9c23_add({&quot;bbox&quot;: [-106.64564599999994, 25.83737700000006, -93.50829199999998, 36.50070400000004], &quot;features&quot;: [{&quot;bbox&quot;: [-96.06485999999995, 31.50405600000005, -95.25885899999997, 32.084475000000054], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-96.06485999999995, 31.98094700000007], [-96.06304799999998, 31.982008000000064], [-96.06184899999994, 31.985159000000067], [-96.06078499999995, 31.986929000000032], [-96.05971499999998, 31.987422000000038], [-96.05762699999997, 31.986710000000073], [-96.05649799999998, 31.98776600000008], [-96.05672599999997, 31.990869000000032], [-96.05378499999995, 31.993021

# %% [markdown]
# Let's use what we learned in the previous sections to join the `df` DataFrame to our `tx` GeoDataFrame!
#
# This is a non-spatial join, so it will use the pandas [merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html#pandas.DataFrame.merge) method.

# %%
joined_df = tx.merge(df, on="FIPS")
joined_df.head()
# Out:
#     FIPS                                           geometry           COUNTY
# 0  48001  MULTIPOLYGON (((-96.06486 31.98095, -96.06305 ...  Anderson County  \
# 1  48003  MULTIPOLYGON (((-103.06470 32.52219, -103.0004...   Andrews County
# 2  48005  MULTIPOLYGON (((-95.00488 31.42396, -95.00334 ...  Angelina County
# 3  48007  MULTIPOLYGON (((-97.12560 28.25371, -97.12500 ...   Aransas County
# 4  48009  MULTIPOLYGON (((-98.95382 33.49637, -98.95377 ...    Archer County
#
#                  LOCATION    AREA_SQMI  E_TOTPOP  M_TOTPOP       Alex
# 0  Anderson County, Texas  1062.616344     58077         0  000048001
# 1   Andrews County, Texas  1500.720658     18362         0  000048003
# 2  Angelina County, Texas   797.864652     86608         0  000048005
# 3   Aransas County, Texas   252.068582     24048         0  000048007
# 4    Archer County, Texas   903.288792      8649         0  000048009

# %%
joined_df.explore(column="E_TOTPOP")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_75f6ad0f0d6453a422cafdbf0808f03e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_75f6ad0f0d6453a422cafdbf0808f03e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_75f6ad0f0d6453a422cafdbf0808f03e = L.map(
#                 &quot;map_75f6ad0f0d6453a422cafdbf0808f03e&quot;,
#                 {
#                     center: [31.16904050000005, -100.07696899999996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_75f6ad0f0d6453a422cafdbf0808f03e);
#
#
#
#
#
#             var tile_layer_22fb629c235c32603a58a6fa1c5689e9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_75f6ad0f0d6453a422cafdbf0808f03e);
#
#
#             map_75f6ad0f0d6453a422cafdbf0808f03e.fitBounds(
#                 [[25.83737700000006, -106.64564599999994], [36.50070400000004, -93.50829199999998]],
#                 {}
#             );
#
#
#         function geo_json_cd995e2c550c30f4cbb82cd5999fdf35_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;99&quot;: case &quot;101&quot;: case &quot;110&quot;: case &quot;161&quot;: case &quot;173&quot;: case &quot;204&quot;: case &quot;213&quot;: case &quot;233&quot;: case &quot;236&quot;: case &quot;248&quot;:
#                     return {&quot;color&quot;: &quot;#450559&quot;, &quot;fillColor&quot;: &quot;#450559&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;49&quot;: case &quot;106&quot;: case &quot;180&quot;: case &quot;234&quot;: case &quot;235&quot;:
#                     return {&quot;color&quot;: &quot;#46075a&quot;, &quot;fillColor&quot;: &quot;#46075a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;12&quot;: case &quot;28&quot;: case &quot;33&quot;: case &quot;44&quot;: case &quot;58&quot;: case &quot;61&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;80&quot;: case &quot;82&quot;: case &quot;85&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;92&quot;: case &quot;94&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;116&quot;: case &quot;120&quot;: case &quot;126&quot;: case &quot;136&quot;: case &quot;140&quot;: case &quot;142&quot;: case &quot;146&quot;: case &quot;149&quot;: case &quot;160&quot;: case &quot;165&quot;: case &quot;168&quot;: case &quot;170&quot;: case &quot;181&quot;: case &quot;182&quot;: case &quot;203&quot;: case &quot;209&quot;: case &quot;224&quot;: case &quot;228&quot;: case &quot;231&quot;: case &quot;238&quot;: case &quot;244&quot;:
#                     return {&quot;color&quot;: &quot;#440256&quot;, &quot;fillColor&quot;: &quot;#440256&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;24&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;48&quot;: case &quot;71&quot;: case &quot;124&quot;: case &quot;129&quot;: case &quot;132&quot;: case &quot;138&quot;: case &quot;162&quot;: case &quot;174&quot;: case &quot;186&quot;: case &quot;200&quot;: case &quot;229&quot;: case &quot;232&quot;: case &quot;240&quot;: case &quot;246&quot;: case &quot;249&quot;:
#                     return {&quot;color&quot;: &quot;#450457&quot;, &quot;fillColor&quot;: &quot;#450457&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;18&quot;: case &quot;115&quot;: case &quot;145&quot;: case &quot;198&quot;:
#                     return {&quot;color&quot;: &quot;#46085c&quot;, &quot;fillColor&quot;: &quot;#46085c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};

# %% [markdown]
# We can also perform spatial joins using the GeoPandas [`sjoin`](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.sjoin.html#geopandas.GeoDataFrame.sjoin) method.
#
# A few important notes:
# * The `predicate` defines what kind of spatial join (see the documentation for more info)
# * The `geometry` column in the result will be geometry of the GeoDataFrame calling the function. (Feel free to swap tx and gdf to see what I mean!)

# %%
intersects = tx.sjoin(gdf, predicate="intersects")
intersects.head()
# Out:
#      FIPS                                           geometry  index_right
# 42  48085  MULTIPOLYGON (((-96.84410 32.98891, -96.84402 ...          243  \
# 56  48113  MULTIPOLYGON (((-97.03852 32.56000, -97.03840 ...          243
# 42  48085  MULTIPOLYGON (((-96.84410 32.98891, -96.84402 ...          113
# 56  48113  MULTIPOLYGON (((-97.03852 32.56000, -97.03840 ...          113
# 42  48085  MULTIPOLYGON (((-96.84410 32.98891, -96.84402 ...           13
#
#    element_type      osmid                                   name    building
# 42     relation    8384532  Engineering and Computer Science West  university
# 56     relation    8384532  Engineering and Computer Science West  university
# 42          way  514361757       Reasearch Operations Center West  university
# 56          way  514361757       Reasearch Operations Center West  university
# 42          way  221345161         Research and Operations Center  university

# %%
intersects.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6a7bc0ac316c31d97393f323ce96265 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6a7bc0ac316c31d97393f323ce96265&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6a7bc0ac316c31d97393f323ce96265 = L.map(
#                 &quot;map_f6a7bc0ac316c31d97393f323ce96265&quot;,
#                 {
#                     center: [32.97535600000006, -96.66687749999997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f6a7bc0ac316c31d97393f323ce96265);
#
#
#
#
#
#             var tile_layer_ae84d6338b686194d7eb98f5700e36d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f6a7bc0ac316c31d97393f323ce96265);
#
#
#             map_f6a7bc0ac316c31d97393f323ce96265.fitBounds(
#                 [[32.545214000000044, -97.03868499999999], [33.40549800000008, -96.29506999999995]],
#                 {}
#             );
#
#
#         function geo_json_5a0f3fbfd640e972cbed22999553ee4f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5a0f3fbfd640e972cbed22999553ee4f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5a0f3fbfd640e972cbed22999553ee4f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5a0f3fbfd640e972cbed22999553ee4f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5a0f3fbfd640e972cbed22999553ee4f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5a0f3fbfd640e972cbed22999553ee4f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5a0f3fbfd640e972cbed22999553ee4f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5a0f3fbfd640e972cbed22999553ee4f = L.geoJson(null, {
#                 onEachFeature: geo_json_5a0f3fbfd640e972cbed22999553ee4f_onEachFeature,
#
#                 style: geo_json_5a0f3fbfd640e972cbed22999553ee4f_styler,
#                 pointToLayer: geo_json_5a0f3fbfd640e972cbed22999553ee4f_pointToLayer
#         });
#
#         function geo_json_5a0f3fbfd640e972cbed22999553ee4f_add (data) {
#             geo_json_5a0f3fbfd640e972cbed22999553ee4f
#                 .addData(data)
#                 .addTo(map_f6a7bc0ac316c31d97393f323ce96265);
#         }
#             geo_json_5a0f3fbfd640e972cbed22999553ee4f_add({&quot;bbox&quot;: [-97.03868499999999, 32.545214000000044, -96.29506999999995, 33.40549800000008], &quot;features&quot;: [{&quot;bbox&quot;: [-96.84412199999997, 32.981490000000065, -96.29506999999995, 33.40549800000008], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-96.84409699999998, 32.98890800000004], [-96.84402499999999, 32.99270900000005], [-96.84398199999998, 32.99731200000008], [-96.84382299999999, 33.003971000000035], [-96.84378999999996, 33.00645100000003], [-96.84377799999999, 33.00777900000003], [-96.84382199999999, 33.00895000000003], [-96.84379299999995, 33.010447000000056], [-96.84379299999995, 33.01047100000

# %% [markdown]
# ## Self-Guided Activities
#
# * Download some data from the Census Bureau (for example their TIGER tract data) and see if you can load and plot it.
# * Explore the [colormaps available through matplotlib](https://matplotlib.org/stable/users/explain/colors/colormaps.html) and use the `cmap` argument to change the color scheme.
# * Can you figure out how to plot both the counties and UTD data in the same map (this will require some Google/documentation)?
# * Playing with Texas counties: create a copy of that GeoDataFrame and plot the convex hulls or centroids of the counties ([check out the docs](https://geopandas.org/en/stable/docs.html)).
